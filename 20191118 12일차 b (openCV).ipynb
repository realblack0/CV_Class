# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
cv2.__version__
# Out:
# '4.1.0'

# %%
dir(cv2)
# Out:
# ['',
#  'ACCESS_FAST',
#  'ACCESS_MASK',
#  'ACCESS_READ',
#  'ACCESS_RW',
#  'ACCESS_WRITE',
#  'ADAPTIVE_THRESH_GAUSSIAN_C',
#  'ADAPTIVE_THRESH_MEAN_C',
#  'AGAST_FEATURE_DETECTOR_AGAST_5_8',
#  'AGAST_FEATURE_DETECTOR_AGAST_7_12D',
#  'AGAST_FEATURE_DETECTOR_AGAST_7_12S',
#  'AGAST_FEATURE_DETECTOR_NONMAX_SUPPRESSION',
#  'AGAST_FEATURE_DETECTOR_OAST_9_16',
#  'AGAST_FEATURE_DETECTOR_THRESHOLD',
#  'AKAZE',
#  'AKAZE_DESCRIPTOR_KAZE',
#  'AKAZE_DESCRIPTOR_KAZE_UPRIGHT',
#  'AKAZE_DESCRIPTOR_MLDB',
#  'AKAZE_DESCRIPTOR_MLDB_UPRIGHT',
#  'AKAZE_create',
#  'AgastFeatureDetector',
#  'AgastFeatureDetector_AGAST_5_8',
#  'AgastFeatureDetector_AGAST_7_12d',
#  'AgastFeatureDetector_AGAST_7_12s',
#  'AgastFeatureDetector_NONMAX_SUPPRESSION',
#  'AgastFeatureDetector_OAST_9_16',
#  'AgastFeatureDetector_THRESHOLD',
#  'AgastFeatureDetector_create',
#  'Algorithm',
#  'AlignExposures',
#  'AlignMTB',
#  'BFMatcher',
#  'BFMatcher_create',
#  'BORDER_CONSTANT',
#  'BORDER_DEFAULT',
# ...

# %%
flags = [i for i in dir(cv2) if i.startswith("IMREAD_")]

# %%
flags
# Out:
# ['IMREAD_ANYCOLOR',
#  'IMREAD_ANYDEPTH',
#  'IMREAD_COLOR',
#  'IMREAD_GRAYSCALE',
#  'IMREAD_IGNORE_ORIENTATION',
#  'IMREAD_LOAD_GDAL',
#  'IMREAD_REDUCED_COLOR_2',
#  'IMREAD_REDUCED_COLOR_4',
#  'IMREAD_REDUCED_COLOR_8',
#  'IMREAD_REDUCED_GRAYSCALE_2',
#  'IMREAD_REDUCED_GRAYSCALE_4',
#  'IMREAD_REDUCED_GRAYSCALE_8',
#  'IMREAD_UNCHANGED']

# %% [markdown]
# > - 대문자는 상수이다.
# - `imread`할때 옵션들을 'IMREAD_'로 시작하도록 정했다.

# %%
im = cv2.imread("practice/1.jpg", cv2.IMREAD_ANYDEPTH)
plt.imshow(im)

# %%
im = cv2.imread("practice/1.jpg", cv2.IMREAD_GRAYSCALE)
plt.imshow(im)

# %%
im = cv2.imread("practice/1.jpg", cv2.IMREAD_REDUCED_COLOR_2)
plt.imshow(im)

# %%
im = cv2.imread("practice/1.jpg", cv2.IMREAD_ANYDEPTH)
plt.imshow(im)

# %%
cv2.IMREAD_UNCHANGED
# Out:
# -1

# %%
im = cv2.imread("practice/1.jpg", cv2.IMREAD_UNCHANGED)
plt.imshow(im)

# %% [markdown]
# > - unchanged는 보통 -1을 사용한다.
# - 채널을 기본적으로 BGR로 불러온다.

# %%
plt.imshow(im[:,:,::-1])

# %% [markdown]
# > - numpy 슬라이싱으로 RGB로 채널 순서 바꿔서 보기

# %%
plt.imshow(np.fliplr(im[:,:,::-1]))

# %% [markdown]
# > - 좌우 반전 시키기

# %%
b, g, r = cv2.split(im)

# %%
from PIL import Image
im_pil = Image.open("practice/1.jpg")
b_pil, g_pil, r_pil = im_pil.split()

# %% [markdown]
# > - PIL과 openCV는 명령어도 거의 유사하다.
# - 차이점은 GPU 지원, backend 종류(python, c), 머신러닝/딥러닝 지원

# %%
np.flip([[1,2], [3,4]])
# Out:
# array([[4, 3],
#        [2, 1]])

# %%
np.flip([[1,2], [3,4]], axis=1)
# Out:
# array([[2, 1],
#        [4, 3]])

# %% [markdown]
# > - `flip`은 이미지를 뒤집을 수 있다.
# - numpy의 함수를 그대로 사용

# %%
# left right

np.fliplr([[1,2], [3,4]])
# Out:
# array([[2, 1],
#        [4, 3]])

# %%
# up down

np.flipud([[1,2], [3,4]])
# Out:
# array([[3, 4],
#        [1, 2]])

# %% [markdown]
# > - axis 개념이 자주 사용되면 쉽게 사용할 수 있게 함수가 있다.

# %%
[i for i in dir(cv2) if i.startswith("COLOR_")]
# Out:
# ['COLOR_BAYER_BG2BGR',
#  'COLOR_BAYER_BG2BGRA',
#  'COLOR_BAYER_BG2BGR_EA',
#  'COLOR_BAYER_BG2BGR_VNG',
#  'COLOR_BAYER_BG2GRAY',
#  'COLOR_BAYER_BG2RGB',
#  'COLOR_BAYER_BG2RGBA',
#  'COLOR_BAYER_BG2RGB_EA',
#  'COLOR_BAYER_BG2RGB_VNG',
#  'COLOR_BAYER_GB2BGR',
#  'COLOR_BAYER_GB2BGRA',
#  'COLOR_BAYER_GB2BGR_EA',
#  'COLOR_BAYER_GB2BGR_VNG',
#  'COLOR_BAYER_GB2GRAY',
#  'COLOR_BAYER_GB2RGB',
#  'COLOR_BAYER_GB2RGBA',
#  'COLOR_BAYER_GB2RGB_EA',
#  'COLOR_BAYER_GB2RGB_VNG',
#  'COLOR_BAYER_GR2BGR',
#  'COLOR_BAYER_GR2BGRA',
#  'COLOR_BAYER_GR2BGR_EA',
#  'COLOR_BAYER_GR2BGR_VNG',
#  'COLOR_BAYER_GR2GRAY',
#  'COLOR_BAYER_GR2RGB',
#  'COLOR_BAYER_GR2RGBA',
#  'COLOR_BAYER_GR2RGB_EA',
#  'COLOR_BAYER_GR2RGB_VNG',
#  'COLOR_BAYER_RG2BGR',
#  'COLOR_BAYER_RG2BGRA',
#  'COLOR_BAYER_RG2BGR_EA',
#  'COLOR_BAYER_RG2BGR_VNG',
#  'COLOR_BAYER_RG2GRAY',
#  'COLOR_BAYER_RG2RGB',
#  'COLOR_BAYER_RG2RGBA',
#  'COLOR_BAYER_RG2RGB_EA',
#  'COLOR_BAYER_RG2RGB_VNG',
#  'COLOR_BGR2BGR555',
# ...

# %%
im_rgb = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.imshow(im_rgb)

# %%
im_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
plt.imshow(im_gray)

# %% [markdown]
# > - 색상 변환은 `cvtColor`를 이용할 수 있다.
# - `COLOR_`로 시작하는 대문자는 색상을 바꾸는데 이용되는 상수이다.
# -  ~ 2 ~ 의 형태로 되어 있어서 from ~ to ~ 라고 생각하면 된다.

# %%
[vars(cv2)[_] for _ in flags]
# Out:
# [4, 2, 1, 0, 128, 8, 17, 33, 65, 16, 32, 64, -1]

# %%
[getattr(cv2, _) for _ in flags]
# Out:
# [4, 2, 1, 0, 128, 8, 17, 33, 65, 16, 32, 64, -1]

# %% [markdown]
# > - flags가 str로 되어 있으므로 for문에 바로 사용할 수 없다.
# - 실제 int값으로 변환해서 사용해야한다.

# %%
im2 = cv2.rotate(im, cv2.ROTATE_90_CLOCKWISE)
plt.imshow(im2)

# %%
[i for i in dir(cv2) if i.startswith("ROTATE_")]
# Out:
# ['ROTATE_180', 'ROTATE_90_CLOCKWISE', 'ROTATE_90_COUNTERCLOCKWISE']

# %% [markdown]
# > - 이미지 회전 시키기
# - cv2는 함수를 이용한다. 왜?
#     - numpy 객체를 이용하기 때문에 메서드를 사용할 수 없기 때문이다.

# %%
cv2.imwrite("practice/2.jpg", im2)
# Out:
# True

# %%
plt.imshow(cv2.imread("practice/2.jpg"))

# %% [markdown]
# > - 이미지 저장하기

# %%
[i for i in dir(cv2) if "FLIP" in i]
# Out:
# []

# %%
plt.imshow(cv2.flip(im, 0))

# %% [markdown]
# > - cv2에서의 filp

# %%
im3 = cv2.line(im, (0,0), (100, 100), (0,0,255), 3)

# %%
plt.imshow(im3)

# %% [markdown]
# > - line 그리기
# - cv2는 docstring이 불친절하다.

# %%
im4 = cv2.rectangle(im, (100,100), (200,200), (255,0,0), 5)

# %%
plt.imshow(im4)

# %% [markdown]
# > - rectangle 그리기
# - cv2는 docstring이 불친절하다.

# %%
# !pip install imutils
# Out:
# ...
#   Created wheel for imutils: filename=imutils-0.5.3-cp37-none-any.whl size=25853 sha256=50ab5d545e23d7faeda23557b958d851baf4041c5d37cc944db791ee2bd23e27
#   Stored in directory: C:\Users\JINHYO\AppData\Local\pip\Cache\wheels\16\84\1f\bf88641293cda2c8be81a5c4b8ca973dd9125a6dc3767417fd
# Successfully built imutils
# ...

# %%
import imutils

# %%
dir(imutils)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'adjust_brightness_contrast',
#  'auto_canny',
#  'build_montages',
#  'check_opencv_version',
#  'convenience',
#  'find_function',
#  'grab_contours',
#  'is_cv2',
#  'is_cv3',
#  'is_cv4',
#  'meta',
#  'opencv2matplotlib',
#  'resize',
#  'rotate',
#  'rotate_bound',
#  'skeletonize',
#  'translate',
#  'url_to_image']

# %%
imutils.find_function("flip")
# Out:
# 1. flip

# %% [markdown]
# > 있을만한 함수 이름 찾아준다.

# %%
im5 = cv2.putText(im, "hello", (0,10), cv2.FONT_HERSHEY_COMPLEX,
            10, (100,100,20))

# %%
plt.imshow(im5)

# %% [markdown]
# > - 유니코드가 지원이 안되서 한글을 못 쓰는 치명적인 단점이 있다.
# - 파이썬 opencv는 내부적으로 C로 되어있어서 C에서 지원안되는 구조라서 파이썬에서 수정할 수 없다.
# - 고수들은 직접 c로 수정해서 쓸 수 있음;

# %%
im6 = cv2.circle(im, (170,170), 50, (0,255,0))

# %%
plt.imshow(im6)

# %% [markdown]
# > - 원 그리기
# - 색상은 튜플로 줄 수 있다.
#     - 그림 그리려는 이미지가 RGB이면 RGB순, BGR순이면 BGR 순으로 색 정보를 입력해야한다.
#     - 이미지가 alpha 채널이 있으면 alpha 값도 줘야한다.

# %%
im7 = cv2.polylines(im, np.array([[[10,20],[300,40],[200,300], [250,150]]]), True, (100,200,50), 15)

# %%
plt.imshow(im7)

# %% [markdown]
# > - pts는 point 찍을 좌표위치를 묶어서 한번에 줘야한다(복수)
# - 2차원 평면이므로 좌표는 2차원으로 만들어줘야한다.
#     - \[10, 20\] ..... (x)
#     - \[\[10, 20\]\] .... (o)
